# %%
import pandas as pd
import numpy as np
from datetime import date
from dateutil.relativedelta import relativedelta

import warnings

# 忽略所有警告
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_excel('df1_output.xlsx', engine='openpyxl')

# %%
df1['统计日期'] = pd.to_datetime(df1['统计截止日期'])

# %%
df1
# Out:
#             统计截止日期    证券代码   其他持股比例  国有法人持股比例       民营指数 是否民营企业       统计日期
# 0       2013-03-31       1  57.3500      1.81  31.685083   民营企业 2013-03-31
# 1       2013-03-31       4  36.0100      0.00        inf   民营企业 2013-03-31
# 2       2013-03-31       5  26.9300      3.64   7.398352   民营企业 2013-03-31
# 3       2013-03-31       7  43.3800      0.00        inf   民营企业 2013-03-31
# 4       2013-03-31       8  69.6900      0.00        inf   民营企业 2013-03-31
# ...            ...     ...      ...       ...        ...    ...        ...
# 111118  2023-12-31  871553  67.4700      0.00        inf   民营企业 2023-12-31
# 111119  2023-12-31  872925  70.8403      0.00        inf   民营企业 2023-12-31
# 111120  2023-12-31  873576  47.6400     30.91   1.541249   民营企业 2023-12-31
# 111121  2023-12-31  873703  80.3100      0.00        inf   民营企业 2023-12-31
# 111122  2023-12-31  873833  60.8500     15.27   3.984938   民营企业 2023-12-31
#
# [111123 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111123 entries, 0 to 111122
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   统计截止日期    111123 non-null  object
#  1   证券代码      111123 non-null  int64
#  2   其他持股比例    111123 non-null  float64
#  3   国有法人持股比例  111123 non-null  float64
#  4   民营指数      111123 non-null  float64
#  5   是否民营企业    111123 non-null  object
#  6   统计日期      111123 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 5.9+ MB

# %%
df1.describe()
# Out:
#                 证券代码         其他持股比例       国有法人持股比例          民营指数
# count  111123.000000  111123.000000  111123.000000  1.111230e+05
# mean   297138.192345      56.129890       2.736248           inf
# std    264811.609215      16.752213       6.152994           NaN
# min         1.000000       0.930000       0.000000  1.000000e+00
# 25%      2517.000000      43.670000       0.000000  2.366825e+01
# 50%    300327.000000      57.350000       0.000000           NaN
# 75%    600697.000000      69.520000       2.180000           NaN
# max    873833.000000     103.600000      49.880000           inf

# %%
df1_filtered = df1[(df1['统计日期'] > '2013-04-01') & (df1['统计日期'] < '2020-12-01')]

# %%
df1_filtered
# Out:
#            统计截止日期    证券代码   其他持股比例  国有法人持股比例       民营指数 是否民营企业       统计日期
# 1151   2013-06-30       1  57.5800      1.81  31.812155   民营企业 2013-06-30
# 1152   2013-06-30       4  37.3600      0.00        inf   民营企业 2013-06-30
# 1153   2013-06-30       5  26.8600      3.64   7.379121   民营企业 2013-06-30
# 1154   2013-06-30       7  44.1400      0.00        inf   民营企业 2013-06-30
# 1155   2013-06-30       8  68.5700      0.00        inf   民营企业 2013-06-30
# ...           ...     ...      ...       ...        ...    ...        ...
# 87070  2020-09-30  688596  55.2800      0.00        inf   民营企业 2020-09-30
# 87071  2020-09-30  688598  55.7400      0.00        inf   民营企业 2020-09-30
# 87072  2020-09-30  688599  55.1400     17.00   3.243529   民营企业 2020-09-30
# 87073  2020-09-30  688600  56.2400     10.64   5.285714   民营企业 2020-09-30
# 87074  2020-09-30  688788  93.7165      0.00        inf   民营企业 2020-09-30
#
# [65553 rows x 7 columns]

# %%
df1_count = df1_filtered.groupby(by=["统计截止日期"]).count()

# %%
df1_count_final = df1_count['证券代码']

# %%
df1_count_final
# Out:
# 统计截止日期
# 2013-06-30    1529
# 2013-09-30    1532
# 2013-12-31    1586
# 2014-03-31    1587
# 2014-06-30    1594
# 2014-09-30    1623
# 2014-12-31    1699
# 2015-03-31    1731
# 2015-06-30    1840
# 2015-09-30    1834
# 2015-12-31    1883
# 2016-03-31    1894
# 2016-06-30    1933
# 2016-09-30    1999
# 2016-12-31    2161
# 2017-03-31    2232
# 2017-06-30    2356
# 2017-09-30    2426
# 2017-12-31    2528
# 2018-03-31    2535
# 2018-06-30    2562
# 2018-09-30    2565
# 2018-12-31    2595
# 2019-03-31    2607
# 2019-06-30    2636
# 2019-09-30    2681
# 2019-12-31    2766
# 2020-03-31    2783
# 2020-06-30    2873
# 2020-09-30    2983
# Name: 证券代码, dtype: int64

# %%
df1_count_final.to_excel('df1_count_final.xlsx')

# %%
df1_count_final.describe()
# Out:
# count      30.000000
# mean     2185.100000
# std       470.307922
# min      1529.000000
# 25%      1756.750000
# 50%      2196.500000
# 75%      2587.500000
# max      2983.000000
# Name: 证券代码, dtype: float64
